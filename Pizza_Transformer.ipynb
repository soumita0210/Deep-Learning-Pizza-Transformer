# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/0a/93/c7bca39b23aae45cd2e85ad3871c81eccc63b9c5276e926511e2e5b0879d/tensorflow_gpu-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 35kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.9MB 38.2MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.9.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.34.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 43.7MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.27.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.18.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.4.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.21.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (46.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.7.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.2.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.8)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=c8c2f75d70d0100a185dad6435cac745704336b0417ff48774be27dcef806bd2
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0rc2 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.1.1 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorflow-estimator<2.3.0,>=2.2.0rc0, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# Installing collected packages: gast, tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
# Successfully installed gast-0.2.2 tensorboard-2.1.1 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0

# %%
from __future__ import absolute_import, division, print_function, unicode_literals


import tensorflow as tf

import tensorflow_datasets as tfds

import os
import re
import numpy as np

import matplotlib.pyplot as plt

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
for file in sorted(os.listdir("drive/My Drive/sparknotes/merged_except_romeo")):
    if file.endswith("_modern.snt.aligned"):
      print(file)
# Out:
# antony-and-cleopatra_modern.snt.aligned
# asyoulikeit_modern.snt.aligned
# errors_modern.snt.aligned
# hamlet_modern.snt.aligned
# henryv_modern.snt.aligned
# juliuscaesar_modern.snt.aligned
# lear_modern.snt.aligned
# macbeth_modern.snt.aligned
# merchant_modern.snt.aligned
# msnd_modern.snt.aligned
# muchado_modern.snt.aligned
# othello_modern.snt.aligned
# richardiii_modern.snt.aligned
# shrew_modern.snt.aligned
# tempest_modern.snt.aligned
# twelfthnight_modern.snt.aligned

# %%
for file in sorted(os.listdir("drive/My Drive/enotes/merged")):
    if file.endswith("_modern.snt.aligned"):
      print(file)
# Out:
# hamlet_modern.snt.aligned
# julius-caesar_modern.snt.aligned
# macbeth_modern.snt.aligned
# merchant-of-venice_modern.snt.aligned
# midsummer-nights-dream_modern.snt.aligned
# othello_modern.snt.aligned
# romeo-and-juliet_modern.snt.aligned
# tempest_modern.snt.aligned

# %%
for file in sorted(os.listdir("drive/My Drive/enotes/merged")):
    if file.endswith("_original.snt.aligned"):
      print(file)
# Out:
# hamlet_original.snt.aligned
# julius-caesar_original.snt.aligned
# macbeth_original.snt.aligned
# merchant-of-venice_original.snt.aligned
# midsummer-nights-dream_original.snt.aligned
# othello_original.snt.aligned
# romeo-and-juliet_original.snt.aligned
# tempest_original.snt.aligned

# %%
for file in sorted(os.listdir("drive/My Drive/sparknotes/merged_except_romeo")):
    if file.endswith("_original.snt.aligned"):
      print(file)
# Out:
# antony-and-cleopatra_original.snt.aligned
# asyoulikeit_original.snt.aligned
# errors_original.snt.aligned
# hamlet_original.snt.aligned
# henryv_original.snt.aligned
# juliuscaesar_original.snt.aligned
# lear_original.snt.aligned
# macbeth_original.snt.aligned
# merchant_original.snt.aligned
# msnd_original.snt.aligned
# muchado_original.snt.aligned
# othello_original.snt.aligned
# richardiii_original.snt.aligned
# shrew_original.snt.aligned
# tempest_original.snt.aligned
# twelfthnight_original.snt.aligned

# %%
questions=[]

for file in sorted(os.listdir("drive/My Drive/sparknotes/merged_except_romeo")):
    if file.endswith("_modern.snt.aligned"):
        filename_concat='drive/My Drive/sparknotes/merged_except_romeo/'+file
        with open(filename_concat) as f:
            lines_modern = f.read().splitlines()

        questions=questions+lines_modern

# %%
len(questions)
# Out:
# 19617

# %%
answers=[]

for file in sorted(os.listdir("drive/My Drive/sparknotes/merged_except_romeo")):
    if file.endswith("_original.snt.aligned"):
        filename_concat='drive/My Drive/sparknotes/merged_except_romeo/'+file
        with open(filename_concat) as f:
            lines_modern = f.read().splitlines()

        answers=answers+lines_modern

# %%
len(answers)
# Out:
# 19617

# %%
questions[11112]
# Out:
# 'Get out, you horrible poison.'

# %%
answers[11112]
# Out:
# 'Out, loathèd medicine!'

# %%
for file in sorted(os.listdir("drive/My Drive/enotes/merged")):
    if file.endswith("_original.snt.aligned"):
        filename_concat='drive/My Drive/enotes/merged/'+file
        with open(filename_concat) as f:
            lines_modern = f.read().splitlines()

        answers=answers+lines_modern

# %%
for file in sorted(os.listdir("drive/My Drive/enotes/merged")):
    if file.endswith("_modern.snt.aligned"):
        filename_concat='drive/My Drive/enotes/merged/'+file
        with open(filename_concat) as f:
            lines_modern = f.read().splitlines()

        questions=questions+lines_modern

# %%
len(questions),len(answers)
# Out:
# (29973, 29973)

# %%
questions[28000],answers[28000]
# Out:
# ('I hear some noise within.', 'I hear some noise within.')

# %% [markdown]
# **Load and preprocess data**
#
# To keep this example simple and fast, we are limiting the maximum length of the sentence to be MAX_LENGTH=40.
# We preprocess our dataset in the following order:
#
#
# 1. Preprocess each sentence by removing special characters in each sentence.
#
# 2. Build tokenizer (map text to ID and ID to text) using TensorFlow Datasets SubwordTextEncoder.
#
# 3. Tokenize each sentence and add START_TOKEN and END_TOKEN to indicate the start and end of each sentence.
#
# 4. Filter out sentence that has more than MAX_LENGTH tokens.
#
# 5. Pad tokenized sentences to MAX_LENGTH

# %%
# Maximum number of samples to preprocess
#MAX_SAMPLES = 50000

def preprocess_sentence(sentence):
  sentence = sentence.lower().strip()
  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
  sentence = re.sub(r'[" "]+', " ", sentence)
  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  sentence = re.sub(r"[^a-zA-Z?.!,]+", " ", sentence)
  sentence = sentence.strip()
  # adding a start and an end token to the sentence
  return sentence


for i in range(len(questions)):
    questions[i]=preprocess_sentence(questions[i])
    
for i in range(len(answers)):
    answers[i]=preprocess_sentence(answers[i])

# %%
# Build tokenizer using tfds for both questions and answers
tokenizer = tfds.features.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13)

# Define start and end token to indicate the start and end of a sentence
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

# Vocabulary size plus start and end token
VOCAB_SIZE = tokenizer.vocab_size + 2

# %%
VOCAB_SIZE
# Out:
# 8038

# %%
tokenizer.vocab_size
# Out:
# 8036

# %%
tokenizer.encode(questions[122])
# Out:
# [289, 34, 1, 12, 1630, 8]

# %%
# Maximum sentence length
MAX_LENGTH = 40


# Tokenize, filter and pad sentences
def tokenize_and_filter(inputs, outputs):
  tokenized_inputs, tokenized_outputs = [], []
  
  for (sentence1, sentence2) in zip(inputs, outputs):
    # tokenize sentence
    sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
    sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN
    # check tokenized sentence max length
    if len(sentence1) <= MAX_LENGTH and len(sentence2) <= MAX_LENGTH:
      tokenized_inputs.append(sentence1)
      tokenized_outputs.append(sentence2)
  
  # pad tokenized sentences
  tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
      tokenized_inputs, maxlen=MAX_LENGTH, padding='post')
  tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
      tokenized_outputs, maxlen=MAX_LENGTH, padding='post')
  
  return tokenized_inputs, tokenized_outputs


questions, answers = tokenize_and_filter(questions, answers)

# %%
print('Vocab size: {}'.format(VOCAB_SIZE))
print('Number of samples: {}'.format(len(questions)))
# Out:
# Vocab size: 8038
# Number of samples: 28545

# %%
type(questions)
# Out:
# numpy.ndarray

# %%
questions.shape
# Out:
# (28545, 40)

# %%
answers.shape
# Out:
# (28545, 40)

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 20000

# decoder inputs use the previous target as input
# remove START_TOKEN from targets
dataset = tf.data.Dataset.from_tensor_slices((
    {
        'inputs': questions,
        'dec_inputs': answers[:, :-1]
    },
    {
        'outputs': answers[:, 1:]
    },
))

dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)

# %%
dataset
# Out:
# <PrefetchDataset shapes: ({inputs: (None, 40), dec_inputs: (None, 39)}, {outputs: (None, 39)}), types: ({inputs: tf.int32, dec_inputs: tf.int32}, {outputs: tf.int32})>

# %%
def scaled_dot_product_attention(query, key, value, mask):
  """Calculate the attention weights. """
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  # scale matmul_qk
  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # add the mask to zero out padding tokens
  if mask is not None:
    logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k)
  attention_weights = tf.nn.softmax(logits, axis=-1)

  output = tf.matmul(attention_weights, value)

  return output

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, d_model, num_heads, name="multi_head_attention"):
    super(MultiHeadAttention, self).__init__(name=name)
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.query_dense = tf.keras.layers.Dense(units=d_model)
    self.key_dense = tf.keras.layers.Dense(units=d_model)
    self.value_dense = tf.keras.layers.Dense(units=d_model)

    self.dense = tf.keras.layers.Dense(units=d_model)

  def split_heads(self, inputs, batch_size):
    inputs = tf.reshape(
        inputs, shape=(batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(inputs, perm=[0, 2, 1, 3])

  def call(self, inputs):
    query, key, value, mask = inputs['query'], inputs['key'], inputs[
        'value'], inputs['mask']
    batch_size = tf.shape(query)[0]

    # linear layers
    query = self.query_dense(query)
    key = self.key_dense(key)
    value = self.value_dense(value)

    # split heads
    query = self.split_heads(query, batch_size)
    key = self.split_heads(key, batch_size)
    value = self.split_heads(value, batch_size)

    # scaled dot-product attention
    scaled_attention = scaled_dot_product_attention(query, key, value, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    # concatenation of heads
    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    # final linear layer
    outputs = self.dense(concat_attention)

    return outputs

# %%
def create_padding_mask(x):
  mask = tf.cast(tf.math.equal(x, 0), tf.float32)
  # (batch_size, 1, 1, sequence length)
  return mask[:, tf.newaxis, tf.newaxis, :]

# %%
def create_look_ahead_mask(x):
  seq_len = tf.shape(x)[1]
  look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
  padding_mask = create_padding_mask(x)
  return tf.maximum(look_ahead_mask, padding_mask)

# %%
class PositionalEncoding(tf.keras.layers.Layer):

  def __init__(self, position, d_model):
    super(PositionalEncoding, self).__init__()
    self.pos_encoding = self.positional_encoding(position, d_model)

  def get_angles(self, position, i, d_model):
    angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
    return position * angles

  def positional_encoding(self, position, d_model):
    angle_rads = self.get_angles(
        position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
        i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
        d_model=d_model)
    # apply sin to even index in the array
    sines = tf.math.sin(angle_rads[:, 0::2])
    # apply cos to odd index in the array
    cosines = tf.math.cos(angle_rads[:, 1::2])

    pos_encoding = tf.concat([sines, cosines], axis=-1)
    pos_encoding = pos_encoding[tf.newaxis, ...]
    return tf.cast(pos_encoding, tf.float32)

  def call(self, inputs):
    return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
def encoder_layer1(units, d_model, num_heads, dropout, name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  attention = MultiHeadAttention(
      d_model, num_heads, name="attention")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention = tf.keras.layers.Dropout(rate=dropout)(attention)
  attention = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention)

  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention + outputs)

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
def encoder_layer2(units, d_model, num_heads, dropout, name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  attention = MultiHeadAttention(
      d_model, num_heads, name="attention")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })
  attention = tf.keras.layers.Dropout(rate=dropout)(attention)
  attention = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention)

  outputs = attention

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
sample_encoder_layer1 = encoder_layer1(
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_encoder_layer")

# %%
sample_encoder_layer2 = encoder_layer2(
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_encoder_layer")

# %%
sample_encoder_layer1.summary()
# Out:
# Model: "sample_encoder_layer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None, 128)]  0
# __________________________________________________________________________________________________
# padding_mask (InputLayer)       [(None, 1, 1, None)] 0
# __________________________________________________________________________________________________
# attention (MultiHeadAttention)  (None, None, 128)    66048       inputs[0][0]
#                                                                  padding_mask[0][0]
#                                                                  inputs[0][0]
#                                                                  inputs[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, None, 128)    0           attention[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_20 (TensorFlowO [(None, None, 128)]  0           inputs[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, None, 128)    256         tf_op_layer_add_20[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, None, 512)    66048       layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, None, 128)    65664       dense_68[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, None, 128)    0           dense_69[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_21 (TensorFlowO [(None, None, 128)]  0           layer_normalization_20[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, None, 128)    256         tf_op_layer_add_21[0][0]
# ==================================================================================================
# Total params: 198,272
# Trainable params: 198,272
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
sample_encoder_layer2.summary()
# Out:
# Model: "sample_encoder_layer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None, 128)]  0
# __________________________________________________________________________________________________
# padding_mask (InputLayer)       [(None, 1, 1, None)] 0
# __________________________________________________________________________________________________
# attention (MultiHeadAttention)  (None, None, 128)    66048       inputs[0][0]
#                                                                  padding_mask[0][0]
#                                                                  inputs[0][0]
#                                                                  inputs[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, None, 128)    0           attention[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_22 (TensorFlowO [(None, None, 128)]  0           inputs[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, None, 128)    256         tf_op_layer_add_22[0][0]
# ==================================================================================================
# Total params: 66,304
# Trainable params: 66,304
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def encoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name="encoder"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  for i in range(num_layers):
    if i==0:
      outputs = encoder_layer2(units=units,d_model=d_model,num_heads=num_heads,dropout=dropout,
        name="encoder_layer_{}".format(i),)([outputs, padding_mask])
    else:
      outputs = encoder_layer1(units=units,d_model=d_model,num_heads=num_heads,dropout=dropout,
        name="encoder_layer_{}".format(i),)([outputs, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
sample_encoder = encoder(
    vocab_size=8149,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_encoder")

# %%
def decoder_layer1(units, d_model, num_heads, dropout, name="decoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name="look_ahead_mask")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention_1")(inputs={
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': look_ahead_mask
      })
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention1 + inputs)

  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention_2")(inputs={
          'query': attention1,
          'key': enc_outputs,
          'value': enc_outputs,
          'mask': padding_mask
      })
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention2 + attention1)

  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention2)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(outputs + attention2)

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)

# %%
def decoder_layer2(units, d_model, num_heads, dropout, name="decoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name="look_ahead_mask")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention_1")(inputs={
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': look_ahead_mask
      })
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention1 + inputs)

  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention_2")(inputs={
          'query': attention1,
          'key': enc_outputs,
          'value': enc_outputs,
          'mask': padding_mask
      })
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention2 + attention1)

  outputs = attention2

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)

# %%
sample_decoder_layer = decoder_layer2(
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_decoder_layer")

# %%
sample_decoder_layer.summary()
# Out:
# Model: "sample_decoder_layer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None, 128)]  0
# __________________________________________________________________________________________________
# look_ahead_mask (InputLayer)    [(None, 1, None, Non 0
# __________________________________________________________________________________________________
# attention_1 (MultiHeadAttention (None, None, 128)    66048       inputs[0][0]
#                                                                  look_ahead_mask[0][0]
#                                                                  inputs[0][0]
#                                                                  inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_26 (TensorFlowO [(None, None, 128)]  0           attention_1[0][0]
#                                                                  inputs[0][0]
# __________________________________________________________________________________________________
# encoder_outputs (InputLayer)    [(None, None, 128)]  0
# __________________________________________________________________________________________________
# padding_mask (InputLayer)       [(None, 1, 1, None)] 0
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, None, 128)    256         tf_op_layer_add_26[0][0]
# __________________________________________________________________________________________________
# attention_2 (MultiHeadAttention (None, None, 128)    66048       encoder_outputs[0][0]
#                                                                  padding_mask[0][0]
#                                                                  layer_normalization_26[0][0]
#                                                                  encoder_outputs[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, None, 128)    0           attention_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_27 (TensorFlowO [(None, None, 128)]  0           dropout_25[0][0]
#                                                                  layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, None, 128)    256         tf_op_layer_add_27[0][0]
# ==================================================================================================
# Total params: 132,608
# Trainable params: 132,608
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def decoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name='decoder'):
  inputs = tf.keras.Input(shape=(None,), name='inputs')
  enc_outputs = tf.keras.Input(shape=(None, d_model), name='encoder_outputs')
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name='look_ahead_mask')
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')
  
  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  for i in range(num_layers):

    if i==0:
      outputs = decoder_layer2(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name='decoder_layer_{}'.format(i),
      )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])
    else:

      outputs = decoder_layer1(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name='decoder_layer_{}'.format(i),
      )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)

# %%
sample_decoder = decoder(
    vocab_size=8149,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_decoder")

# %%
def transformer(vocab_size,
                num_layers,
                units,
                d_model,
                num_heads,
                dropout,
                name="transformer"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")
  dec_inputs = tf.keras.Input(shape=(None,), name="dec_inputs")

  enc_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='enc_padding_mask')(inputs)
  # mask the future tokens for decoder inputs at the 1st attention block
  look_ahead_mask = tf.keras.layers.Lambda(
      create_look_ahead_mask,
      output_shape=(1, None, None),
      name='look_ahead_mask')(dec_inputs)
  # mask the encoder outputs for the 2nd attention block
  dec_padding_mask = tf.keras.layers.Lambda(
      create_padding_mask, output_shape=(1, 1, None),
      name='dec_padding_mask')(inputs)

  enc_outputs = encoder(
      vocab_size=vocab_size,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
  )(inputs=[inputs, enc_padding_mask])

  dec_outputs = decoder(
      vocab_size=vocab_size,
      num_layers=num_layers,
      units=units,
      d_model=d_model,
      num_heads=num_heads,
      dropout=dropout,
  )(inputs=[dec_inputs, enc_outputs, look_ahead_mask, dec_padding_mask])

  outputs = tf.keras.layers.Dense(units=vocab_size, name="outputs")(dec_outputs)

  return tf.keras.Model(inputs=[inputs, dec_inputs], outputs=outputs, name=name)

# %%
sample_transformer = transformer(
    vocab_size=8149,
    num_layers=4,
    units=512,
    d_model=128,
    num_heads=4,
    dropout=0.3,
    name="sample_transformer")

# %%
tf.keras.backend.clear_session()

# Hyper-parameters
NUM_LAYERS = 4
D_MODEL = 256
NUM_HEADS = 8
UNITS = 512
DROPOUT = 0.1

model = transformer(
    vocab_size=VOCAB_SIZE,
    num_layers=NUM_LAYERS,
    units=UNITS,
    d_model=D_MODEL,
    num_heads=NUM_HEADS,
    dropout=DROPOUT)

# %%
model.load_weights('drive/My Drive/dl/trans_shakes.h5')

# %%
def loss_function(y_true, y_pred):
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
  
  loss = tf.keras.losses.SparseCategoricalCrossentropy(
      from_logits=True, reduction='none')(y_true, y_pred)

  mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
  loss = tf.multiply(loss, mask)

  return tf.reduce_mean(loss)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps**-1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(
    learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

def accuracy(y_true, y_pred):
  # ensure labels have shape (batch_size, MAX_LENGTH - 1)
  y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
  return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])

# %%
#20

EPOCHS = 20

model.fit(dataset, epochs=EPOCHS)

model.save_weights('drive/My Drive/dl/trans_shakes_without_romeo2.h5')
# Out:
# Train for 447 steps
# Epoch 1/20
# 447/447 [==============================] - 1245s 3s/step - loss: 2.3333 - accuracy: 0.0361
# Epoch 2/20
# 447/447 [==============================] - 1215s 3s/step - loss: 1.6831 - accuracy: 0.0829
# Epoch 3/20
# 447/447 [==============================] - 1217s 3s/step - loss: 1.4790 - accuracy: 0.0992
# Epoch 4/20
# 447/447 [==============================] - 1232s 3s/step - loss: 1.3525 - accuracy: 0.1112
# Epoch 5/20
# 447/447 [==============================] - 1234s 3s/step - loss: 1.2401 - accuracy: 0.1239
# Epoch 6/20
# 447/447 [==============================] - 1230s 3s/step - loss: 1.1322 - accuracy: 0.1364
# Epoch 7/20
# 447/447 [==============================] - 1236s 3s/step - loss: 1.0349 - accuracy: 0.1484
# Epoch 8/20
# 447/447 [==============================] - 1227s 3s/step - loss: 0.9464 - accuracy: 0.1582
# Epoch 9/20
# 447/447 [==============================] - 1255s 3s/step - loss: 0.8684 - accuracy: 0.1669
# Epoch 10/20
# 447/447 [==============================] - 1251s 3s/step - loss: 0.7849 - accuracy: 0.1771
# Epoch 11/20
# 447/447 [==============================] - 1217s 3s/step - loss: 0.6919 - accuracy: 0.1888
# Epoch 12/20
# 447/447 [==============================] - 1234s 3s/step - loss: 0.6084 - accuracy: 0.2004
# Epoch 13/20
# 447/447 [==============================] - 1225s 3s/step - loss: 0.5344 - accuracy: 0.2112
# Epoch 14/20
# 447/447 [==============================] - 1217s 3s/step - loss: 0.4712 - accuracy: 0.2209
# Epoch 15/20
# 447/447 [==============================] - 1232s 3s/step - loss: 0.4177 - accuracy: 0.2297
# Epoch 16/20
# 447/447 [==============================] - 1206s 3s/step - loss: 0.3694 - accuracy: 0.2385
# Epoch 17/20
# 447/447 [==============================] - 1211s 3s/step - loss: 0.3251 - accuracy: 0.2461
# Epoch 18/20
# 447/447 [==============================] - 1220s 3s/step - loss: 0.2899 - accuracy: 0.2528
# Epoch 19/20
# 447/447 [==============================] - 1209s 3s/step - loss: 0.2590 - accuracy: 0.2592
# Epoch 20/20
# 447/447 [==============================] - 1205s 3s/step - loss: 0.2341 - accuracy: 0.2646

# %%
model.save_weights('drive/My Drive/dl/trans_shakes_without_romeo20.h5')

# %%
def evaluate(sentence):
  sentence = preprocess_sentence(sentence)

  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  output = tf.expand_dims(START_TOKEN, 0)

  for i in range(MAX_LENGTH):
    predictions = model(inputs=[sentence, output], training=False)

    # select the last word from the seq_len dimension
    predictions = predictions[:, -1:, :]
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # return the result if the predicted_id is equal to the end token
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # concatenated the predicted_id to the output which is given to the decoder
    # as its input.
    output = tf.concat([output, predicted_id], axis=-1)

  return tf.squeeze(output, axis=0)


def predict(sentence):
  prediction = evaluate(sentence)

  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('Input: {}'.format(sentence))
  print('Output: {}'.format(predicted_sentence))

  return predicted_sentence

# %%
inp = 'Why, Romeo, are you crazy?'
output=predict(inp)
# Out:
# Input: Why, Romeo, are you crazy?
# Output: why , romeo , are you mad ?

# %%
output = predict('have you killed Tybalt ?')
# Out:
# Input: have you killed Tybalt ?
# Output: hast thou slain tybalt ?

# %%
output = predict('bring her out to me .')
# Out:
# Input: bring her out to me .
# Output: bring her to me .

# %%
output = predict('i will hit you !')
# Out:
# Input: i will hit you !
# Output: i will strike thee !

# %%
output = predict('Look what you made me do .')
# Out:
# Input: Look what you made me do .
# Output: look what thou hast wronged me .

# %%
output = predict('Don’t worry about me .')
# Out:
# Input: Don’t worry about me .
# Output: fear me not .

# %%
output = predict('What is wrong with you ?')
# Out:
# Input: What is wrong with you ?
# Output: what is thy wrong with thee ?

# %%
output = predict('You are so bad !')
# Out:
# Input: You are so bad !
# Output: o thou unhappy commoner .

# %%
output = predict('Father, please! Help me!')
# Out:
# Input: Father, please! Help me!
# Output: my father ! i pray you , help me !

# %%
output = predict('What fight was here?')
# Out:
# Input: What fight was here?
# Output: what fray was here ?

# %%
inp = 'i ’ ll bite you by the ear for that joke .'
output=predict(inp)
# Out:
# Input: i ’ ll bite you by the ear for that joke .
# Output: i will bite thee by the parlous sweetly .

# %%
output = predict('I am very happy .')
# Out:
# Input: I am very happy .
# Output: i am much merry .

# %%
output = predict('Good bye, Mr. Anderson.')
# Out:
# Input: Good bye, Mr. Anderson.
# Output: farewell , monsieur and most humble host .

# %%
output = predict('what do you want ? ')
# Out:
# Input: what do you want ?
# Output: what s your will ?

# %%
import nltk 
from nltk import bleu
import re
from nltk.translate.bleu_score import SmoothingFunction
smoothie = SmoothingFunction().method4


def bleuscore(inp,predict):

  
  line = re.sub(r"[^A-Za-z\s]", "", inp.strip())
  words = line.split()
  inp=' '.join(words)

  line = re.sub(r"[^A-Za-z\s]", "", predict.strip())
  words = line.split()
  predict=' '.join(words)

  #print(inp,predict)

  ref=inp.split()
  hypo=predict.split()
  
  
  #score=nltk.translate.bleu_score.sentence_bleu([ref], hypo)
  #score=bleu([ref],hypo,smoothing_function=smoothie)
  score=bleu([ref],hypo)
  print(score)
  return score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
with open('untitled_text.txt') as f:
            lines_m = f.read().splitlines()

# %%
lines_m=np.array(lines_m)
np.random.shuffle(lines_m)

# %%
np.save('test.npy',lines_m[:1000])

# %%
inputs=lines_m[:1000]
counter=1000
summ=0
for inp in inputs:

  output=predict(inp)
  x=bleuscore(inp,output)
  if x==0:
    counter-=1
  summ+=x

print(summ/counter)
# Out:
# Input: For my own good, All other problems will have to wait.
# Output: for mine own all causes shall give way .
# 0.40866465020165643
# Input: Does the king leave here today?
# Output: goes the king hence today ?
# 0.5095231471606585
# Input: It’s just midnight.
# Output: it is now midnight .
# 0.7071067811865476
# Input: I cannot tell.
# Output: i cannot tell .
# 0.7598356856515925
# Input: O Dardanius!
# Output: o dardanius !
# 0
# Input: Good God, soon we’ll remove The thing that makes us strangers!
# Output: good god , betimes remove the means that makes us strangers !
# 0.2513293635022765
# Input: Get up, I say.
# Output: arise , i say !
# 0.5444460596606694
# Input: Wait!
# Output: soft !
# 0
# Input: Honestly, then I’m afraid you are dammed both by father and mother; when I keep away from the Sea Monster, your father, I fall into an equal evil, your mother; well, you are gone both ways.
# Output: then fear then i fear you are swift of father and when i have cast away off the sea into the sea monster , i doubt i fall to your mother .
# 0.36926395395253053
# Input: You have taken it more seriously than I meant you to.
# Output: you have taken it wiselier than i meant you should .
# 0.35979535642857696
# Input: No more yet about this; Because it is a story of day by day, Not a story for a breakfast or Befitting this first meeting.
# Output: no more yet yet of this , for tis a chronicle of day a relation for a breakfast , or befitting this first meeting .
# 0.176505590219344
# Input: O fool!
# Output: o fool !
# 0.8408964152537145
# Input: My lord, there wasn’t any such stuff in my thoughts.
# Output: my lord , there was no such stuff in my thoughts .
# 0.4518010018049224
# Input: So goodbye until we shall meet again.
# Output: so fare you well , till we shall meet again .
# 0.2984745896009823
# Input: I hear a voice that is more shrill than all the music Yelling, "Caesar"!
# Output: i hear a tongue , shriller than all the music , cry caesar . cry caesar . stay , caesar is more than all this .
# 0.16195570128532405
# Input: I would govern with perfection like yours, sir, To surpass the golden age.
# Output: i would with such perfection govern , sir , to alonso i would with such perfection govern , sir .
# 0.7476743906106103
# Input: Most constantly.
# Output: most constantly .
# 0.8408964152537145
# Input: with Lysander?
# Output: with lysander ?
# 0.8408964152537145
# Input: what, gone?
# Output: what , gone ?
# 1.0
# Input: Kind souls, what, do you weep when you only see Our Caesar's clothes wounded?
# Output: kind souls , what , weep when thou weep st but behold our caesar s wounded ?
# 0.4841524713034601
# Input: Do you intend to sink us?
# Output: have you a mind to sink ?
# 0.5623413251903491
# Input: The crow sings as sweetly as the lark When either is waited on, and I think The nightingale, if she sang by day, When every goose is cackling, would be considered No better a musician than the wren.
# Output: the crow aside the oars were strong report of the air doth lack air and hold her late when she shall be paid by every day as she shall not hate the quick .
# 0.6376308496660346
# Input: It is certain, then, for Cyprus.
# Output: tis certain then for cyprus .
# 0.4604061366599648
# Input: Out, damned spot!
# Output: out , damned spot !
# 0.7598356856515925
# Input: Let’s break up our watch, and I think We should tell all we have seen tonight To young Hamlet, for, I swear on my life, This spirit, silent to us, will speak to him.
# Output: let s all embrace , and there be night lest we have seen tonight , be seen at young fortune , i swear on this mortal life .
# 0.08773466038559055
# Input: The sooner, sweet, for you.
# Output: the sooner , sweet , for you .
# 0.668740304976422
# Input: Dead, dead?
# Output: dead , dead ?
# 0.8408964152537145
# Input: Difficult to question, but, when we ask for something, He is most free in his reply.
# Output: niggard of question , but of our demands most free in his reply .
# 0.26126779873800154
# Input: Wait for me, if you dare; Because I know well That you are running before me, moving from place to place, Not daring to stand still or look me in the face.
# Output: attend me , if thou darest for well i know thee ere tarrying hence , shifting thy place , whose hands or meet not in the face .
# 0.1597441808764184
# Input: How badly this candle burns!
# Output: how ill this taper burns !
# 0.7952707287670506
# Input: There are more things in heaven and earth, Horatio, Than are dreamt of in your philosophy.
# Output: there are more things in heaven and earth , horatio , than are dreamt of in your philosophy .
# 0.6739047062564734
# Input: Come on, sir.
# Output: come on , sir .
# 0.7598356856515925
# Input: Do you see this, O God?
# Output: do you see this , o god ?
# 0.4728708045015879
# Input: If it’s found to be so, someone will dearly pay for it.
# Output: if it be found so , some will dear abide it .
# 0.688467755321249
# Input: God, we are her privates.
# Output: faith , she privates we .
# 0.6548907866815301
# Input: What's happened, That such a hideous trumpet calls to summon The sleepers of the house?
# Output: what s the business , that such a hideous trumpet calls to parley the sleepers of the house ?
# 0.42818185319516083
# Input: For my part, my lord, I didn’t intend to see you here; But, meeting with Salanio by the way, He begged me, past all saying no, To come along with him.
# Output: for my part , my part , come not to see thee but here with the waymities he will bring thee here by the way .
# 0.22526658131515162
# Input: Do you know them?
# Output: do you know them ?
# 0.7071067811865476
# Input: If the balance of our lives had not one scale of reason to balance another of sensuality, the blood and baseness of our natures would lead us to very preposterous conclusions.
# Output: if the excuse of our lives were not to hand of another imptsadtsturing of those that would lead to a fairer beg of our power to lead to under .
# 0.20982909853373996
# Input: Doesn’t it go well?
# Output: doth it not go well ?
# 0.6223329772884784
# Input: What, ho!
# Output: what , ho !
# 0.8408964152537145
# Input: So I did, Fearing that I might make you more impatient When you seemed already fired up, and besides, I was hoping it was just a bad mood, Which sometimes hits every man.
# Output: so do i fear , fearing further , when thou didst die for when thou art old , i stood within the confusion i took it as he makes a strange man .
# 0.4940582173691989
# Input: How it grieved Macbeth!
# Output: how it did grieve macbeth !
# 0.668740304976422
# Input: No, by this heavenly light!
# Output: no , by this heavenly light !
# 0.668740304976422
# Input: So is Lysander.
# Output: so is lysander .
# 0.7598356856515925
# Input: So you think you won’t marry again, But you’ll change your mind when your first lord is dead.
# Output: think yourself your highness will not marry thee , but your first when your first is dead .
# 0.25655541222096606
# Input: Who are they that do play it?
# Output: what are they that do play it ?
# 0.8091067115702212
# Input: No.
# Output: no .
# 0
# Input: Why, no; the day dawned Before we parted.
# Output: why , no the day that we did take it .
# 0.3549481056010053
# Input: Tonight, my lord?
# Output: tonight , my lord ?
# 0.7598356856515925
# Input: What do you think about that?
# Output: what think you of that ?
# 0.7205745450576256
# Input: Master young man, you, please; which is the way to Master Jew's?
# Output: master , young man , you , which is the way to jew s ?
# 0.42846977766678973
# Input: For us and for our tragedy, Here stooping to your clemency, We beg you listen patiently.
# Output: for us , and for our tragedy , here stooping to your clemency , we beg your hearing patiently .
# 0.40325042950627804
# Input: O wretched villain!
# Output: o wretched villain !
# 0.7598356856515925
# Input: I kissed you before I killed you.
# Output: i kiss thee ere i kill thee .
# 0
# Input: I believe that this applause is For some new honors that are to be heaped on Caesar.
# Output: i do believe that these applauses are for some new honors that are heap d on caesar .
# 0.2545984531673679
# Input: Shall Caesar send a lie?
# Output: shall caesar send a lie ?
# 0.5623413251903491
# Input: Of all men else I have avoided you.
# Output: of all men else i have avoided thee .
# 0.45966135761245924
# Input: This chest threatens; men that gamble everything Do it in hope of a better advantage: A golden mind doesn’t stoop to shows of scum; Then I won’t give or gamble anything for lead.
# Output: this speed of their arms doth therefore hang them in virtue on a fairer equivocation will make a golden devil his devil s devil or devil hang dishonoried for their unspotal .
# 0.6218396214324063
# Input: Is it possible?
# Output: is t possible ?
# 0.7598356856515925
# Input: To speak honestly, and with no addition to the facts, We go to gain a little patch of ground That’s not worth anything except its name.
# Output: truly to speak with no addition , and we go to gain a little patch of ground that hath in it no profit but the name .
# 0.34487396730272046
# Input: Sir, I have done all this service Since I left you.
# Output: aside to prospero sir , all this service aside to prospero sir , all this service aside to prospero sir , all that i have done since i went .
# 0.1760928267911618
# Input: Good Hamlet, take off your black looks, And let your eye look on the King like a friend.
# Output: good hamlet , take thy nightly eyes and look thy eye on a friend where it looks like the king .
# 0.4027672046365773
# Input: My heart journeyed to her only like a guest, And now has returned home to Helena, There to remain.
# Output: my heart to her but like a patient logand now now is going home to helen .
# 0.4661973329389529
# Input: I’ll have you speak out the rest of this soon.
# Output: i will have thee speak out the rest of this soon .
# 0.5900468726392808
# Input: Is it possible a young maid's sanity Should be die as does an old man?
# Output: is it possible a young youth should be as mortal as doth an old man doth be so old man s life ?
# 0.1665240823401981
# Input: Please do this carefully, that he will be more in love with her than she is with him.
# Output: i pray you , do this ware er of love and make it render me more than she is kind .
# 0.24515235346013312
# Input: How many times will Caesar bleed in amusement, That lies now next to Pompey's statue, No worthier than the dust!
# Output: how many times shall caesar bleed in sport , that now on pompey s basis lies along no worthier than the dust !
# 0.1624355752882384
# Input: Come over here; I am here.
# Output: come hither i am here .
# 0.4604061366599648
# Input: He’s or taken or slain.
# Output: he is or ta en or slain .
# 0.5169731539571706
# Input: Oh excellent!
# Output: o excellent !
# 0.8408964152537145
# Input: No, how will you do for a husband?
# Output: no , how will you do for a husband ?
# 0.8408964152537145
# Input: I wonder why they are here together.
# Output: i wonder of their being here together .
# 0.5169731539571706
# Input: What do you mean by this?
# Output: what mean st thou by this ?
# 0.5623413251903491
# Input: And then, sir, ask if he does this, does he--What was I about to say?
# Output: and then , sir , does he this he does what was i about to say ?
# 0.342515953735076
# Input: Go carry them, and smear The sleepy guards with blood.
# Output: go carry them , and smear the sleepy grooms with blood .
# 0.32466791547509893
# Input: We must not now displease him.
# Output: we must not now displease him .
# 0.7598356856515925
# Input: Is that the law?
# Output: is that the law ?
# 0.7071067811865476
# Input: The King rises.
# Output: the king rises .
# 0.7598356856515925
# Input: Brutus, don’t scold me, I won’t put up with it.
# Output: brutus , bait not me , i will not endure it .
# 0.6143868746168435
# Input: Do you believe his “offers,” as you call them?
# Output: do you believe his tenders , as you call them ?
# 0.43167001068522526
# Input: Her mood must be pitied.
# Output: her mood will needs be pitied .
# 0.5623413251903491
# Input: He has legs like a man, and his fins look like arms!
# Output: legged like a man , and his fins like arms !
# 0.473364131565402
# Input: My cause is fixed in my heart; yours has no less reason.
# Output: my cause is hearted thine hath no less reason .
# 0.3114911161085251
# Input: How can it be otherwise?
# Output: what is it else ?
# 0.5506953149031838
# Input: I will not speak with her.
# Output: i will not speak with her .
# 0.7598356856515925
# Input: I will put my arms around you just as the woodbine twists around the sweet honeysuckle,— like the female ivy Winds around the branches of the elm.
# Output: so doth the sweet proportion of the sweet honeysuckle gently entwist the female ivy so enrings the barky fingers of the elm .
# 0.3048210911863494
# Input: Or is your gold and silver ewes and rams?
# Output: or is your gold and silver ewes and rams ?
# 0.8633400213704505
# Input: No, in all confidence, the Turks are not going to Rhodes.
# Output: nay , in all confidence , he s not for rhodes .
# 0.2842202242491899
# Input: Laertes, you shall hear them.
# Output: laertes , you shall hear them .
# 0.668740304976422
# Input: O, banish me, my lord, but don’t kill me!
# Output: o , banish me , my lord , but kill me not !
# 0.5133450480401704
# Input: Shall Rome stand under one man's awe?
# Output: shall rome stand under one man s awe ?
# 0.392814650900513
# Input: In religion, What damned error is there that some sober face Will bless it, and approve it with a text, Hiding the grossness with a beautiful ornament?
# Output: in religion , what damned error , but some sober brow will bless it , and approve it with a text , hiding the grossness with fair ornament ?
# 0.3532200430787858
# Input: And will you tear our ancient love apart To join with men in scorning your poor friend?
# Output: and will you rent our ancient love asunder , to join with men in scorning your poor friend ?
# 0.5312583871630396
# Input: Nymph, in your eyes May all my sins be remembered.
# Output: nymph , in thy orisons be all my sins remembered .
# 0.3515059938464902
# Input: O, pardon, sir, it does, and the gray lines over there That adorn the clouds are the messengers of dawn.
# Output: o , pardon , sir , it doth , and yon grey lines that fret the clouds are messengers of day .
# 0.33166126780871225
# Input: I think it does.
# Output: i think it doth .
# 0.6389431042462724
# Input: You promised To give it to me after a full year.
# Output: you gave it yourself into a full year .
# 0.2699772981159411
# Input: Have you heard the story?
# Output: have you heard the argument ?
# 0.5623413251903491
# Input: Would you do such a deed for all the world?
# Output: wouldst thou do such a deed for all the world ?
# 0.7598356856515925
# Input: Arise, black vengeance, from your hollow hell!
# Output: arise , black vengeance , from thy hollow cell !
# 0.4417918226831577
# Input: Argh!
# Output: foh !
# 0
# Input: Say when.
# Output: say , when ?
# 0.8408964152537145
# Input: A lazy disposition, my good lord.
# Output: a truant disposition , good my lord .
# 0.9036020036098448
# Input: I have observed that the air is delicate In areas where they frequently breed and visit.
# Output: i have seen that the air is bred so foul a deed as they are .
# 0.17032825081616243
# Input: Stephano is my name, and I bring word that My mistress will be here at Belmont Before the break of day; she wanders about By holy crosses, where she kneels and prays For happy marriage hours.
# Output: stephano is my name , and i bring word my mistress will before the break of day before the day s death break of her years , and cross every day to painted where she is from ourselvesr
# 0.16625131470499446
# Input: I have done the deed.
# Output: i have done the deed .
# 0.668740304976422
# Input: Is your marriage here?
# Output: is thy union here ?
# 0.7071067811865476
# Input: No, Caesar doesn’t have it; but you, and I, And honest Casca, we have epilepsy.
# Output: no , caesar hath it not , but you , and i , and honest casca , we have the falling sickness .
# 0.26784884804296605
# Input: Disgustingly filthy rumors are circulating.
# Output: foul whisperings are abroad .
# 0.5506953149031838
# Input: If it takes on my noble father's appearance, I’ll speak to it, though hell itself should open wide And order me to be silent.
# Output: if it assume my noble father s person , i ll speak to it , though hell itself should gape and bid me hold my peace .
# 0.27876286341624873
# Input: Away!
# Output: away !
# 0
# Input: aren’t you the guy That scares the maidens of the village; Skims cream from milk, and sometimes works the churn, And, bootless, makes the breathless housewife churn even harder; And sometimes makes the drink so that it doesn’t have a yeasty foam; Misleads wanderers who are out at night, laughing at their getting lost?
# Output: are you not the gentleman that sits at the meal of the emperor , and silence burnt without the brains are sunburnt in the heat and smooth aught there ?
# 0.13722848694931755
# Input: I beg you, do so.
# Output: prithee , do so .
# 0.39011264866539486
# Input: I charge you, go with me.
# Output: i charge you , go with me and go with me .
# 0.392814650900513
# Input: His madness.
# Output: his madness .
# 0.8408964152537145
# Input: Why, there was a crown offered to him, and when it was Offered to him, he pushed it away with the back of his hand, like this, And then the people started shouting.
# Output: why , there was a crown offered him and , when in the next turning him with his hand .
# 0.13109557943759906
# Input: You said the enemy would not come down, But keep the hills and upper regions.
# Output: you said the enemy would not come down , but keep the hills and upper regions .
# 0.7241577342575828
# Input: Let me see: “Who chooses me shall gain what many men desire.” What many men desire!
# Output: let me see who chooseth me , shall gain what many men desire .
# 0.40890620307453723
# Input: Do you think that I’m no stronger than my sex, Being so fathered and so married?
# Output: think you that i am no stronger than my sex , being so father d and so husbanded ?
# 0.2756966158898809
# Input: I am one, sir, that comes to tell you your daughter and the Moor are now making a Satan.
# Output: i am one , sir , that comes to tell you your daughter and the moor are now making the beast with two backs .
# 0.5758522372341492
# Input: Nothing’s ours, all's been spent, Where we got what we wanted, but without content.
# Output: nought s had , all s spent , where our desire is got without content .
# 0.37053273356129773
# Input: The queen, your mother, in most great affliction of spirit, has sent me to you.
# Output: the queen , your mother , in most great affliction of spirit , hath sent me to you .
# 0.7241577342575828
# Input: O Gertrude, let’s go!
# Output: o gertrude , come away !
# 0
# Input: For shame!
# Output: fie !
# 0
# Input: We told him about them, And it seemed to make him happy To hear of it.
# Output: we told him of them , and it unto a kind of right glad of it .
# 0.45739090263062027
# Input: And look where Publius is coming to go get me.
# Output: and look where publius is come to fetch me .
# 0.45936133207830593
# Input: Truly, my name is Cinna.
# Output: in faith , my name is cinna .
# 0.4728708045015879
# Input: Remember it, my lord!
# Output: remember it , my lord !
# 0.7071067811865476
# Input: On him, on him!
# Output: on him , on him !
# 0.7071067811865476
# Input: I beg you, sit still.
# Output: pray you , sit still .
# 0.5506953149031838
# Input: Put money in your purse; follow the wars; defeat your mood with an false beard; I say, put money in your purse.
# Output: put money in thy purse follow thou the wars that thy favor with an usurped beard .
# 0.24004753520875904
# Input: Mine, sir.
# Output: mine , my lord .
# 0
# Input: Drunk?
# Output: drunk ?
# 0
# Input: I get great comfort from this fellow.
# Output: i get great comfort from this fellow .
# 0.8091067115702212
# Input: Good sentences, and well said.
# Output: good sentences , and well pronounced .
# 0.5623413251903491
# Input: Where are you?
# Output: where art thou ?
# 0
# Input: If these are true eyes in my head, here's a goodly sight.
# Output: if these are true spies which i wear in my head , here s a goodly sight .
# 0.4685909905380384
# Input: And make him break his promise with fair Aegle, Not to mention with Ariadne and Antiopa?
# Output: and make him with fair aegle break his faith , not with ariadne and antiopa ?
# 0.522387642241613
# Input: my wife!
# Output: my wife !
# 1.0
# Input: I know our country’s disposition well; In Venice they let heaven see the pranks They wouldn’t dare show their husbands; their best conscience Isn’t to leave it unfinished, but to keep it unknown.
# Output: i know our country s preroents and the horned they shall not show their husbands but let their husbands harms better lives in their husbands drops of reeds .
# 0.16533086644930767
# Input: I, Beyond all limit of whatever else in the world, Do love, prize, honor you.
# Output: i , beyond all limit of what else i th world , do love , prize , prize , honor you .
# 0.4045533557851106
# Input: If partially connected or together in office, You deliver more or less than truth, You are no soldier.
# Output: if partially affined , or less in office , thou deliver st , thou art no soldier .
# 0.45284630216185867
# Input: Sir, there was a kind of fighting in my heart That wouldn’t let me sleep.
# Output: sir , there was a kind of fighting that would not let me sleep .
# 0.4153498859714258
# Input: What horrible desire is this?
# Output: what horrible fancy s this ?
# 0.7952707287670506
# Input: Awake, awake!
# Output: awake , awake !
# 0.8408964152537145
# Input: I’ll grant you that I’m a woman, but I am, besides, A woman that Lord Brutus married.
# Output: i grant i am a woman , but withal a woman that lord brutus took to wife .
# 0.2641353933218273
# Input: It is not needed yet.
# Output: tis not needed yet .
# 0.5506953149031838
# Input: This sin of greediness Digs in deeper; grows with a more dangerous root Than summer-seeming lust; and it has been The sword of our slain kings.
# Output: this avarice sticks deeper , grows with more pernicious root than summer seeming lust , and it hath been the sword of our slain kings .
# 0.2364870955811728
# Input: Why does he allow this rude fellow to knock him about the head now, with a dirty shovel, and will not tell him why he’s being hit?
# Output: why does he suffer this rude knave of the house to knock him now , with a dirty shovel , and will not tell him of battery ?
# 0.4392283615599068
# Input: And for that purpose, I’ll poison my sword.
# Output: and for that purpose i ll poison my sword .
# 0.5555238068023582
# Input: He doesn’t miss much.
# Output: he misses not .
# 0
# Input: It seems it is as proper for our age To cast beyond ourselves in our opinions As it is common for the younger sort To lack discretion.
# Output: it seems to be as proper to our age to cast beyond ourselves in our opinions as it is common for the younger sort to lack discretion .
# 0.4579308259228105
# Input: I don’t, sir.
# Output: i do not , sir .
# 0.7071067811865476
# Input: You, like an exorcist, have brought my dead Spirit back to life.
# Output: thou , like an exorcist , hast conjured up my mortified spirit .
# 0.2658156069371863
# Input: Haven’t Those in charge of it returned yet?
# Output: are those in commission returned ?
# 0.43645382979233377
# Input: Happily this is the second time he uses them, for they say an old man is twice a child.
# Output: happily he s the second time come to them , for they say an old man is twice a child .
# 0.6272517339014033
# Input: It was, so please your highness.
# Output: it was , so please your highness .
# 0.7598356856515925
# Input: What, my lord?
# Output: what , my lord ?
# 0.7598356856515925
# Input: Take in the top sail.
# Output: take in the topsail .
# 0.49760938992507125
# Input: Why, Antony.
# Output: why , antony .
# 0
# Input: For Hecuba?
# Output: for hecuba !
# 0
# Input: My name's Macbeth.
# Output: my name s macbeth .
# 0
# Input: First, Pyramus must draw a sword to kill himself, which the ladies cannot stand.
# Output: first , pyramus must draw a sword to kill himself which the ladies cannot abide .
# 0.7577395672414201
# Input: Hail, King of Scotland!
# Output: hail , king of scotland !
# 0.7071067811865476
# Input: Transparent Helena!
# Output: transparent helena !
# 0
# Input: O, let the heavens Give him defense against the elements, Because I have lost him on a dangerous sea!
# Output: o , let the heavens give him defense against the elements , for i have lost him on a dangerous sea .
# 0.5685488870277223
# Input: Why, I will fight with him upon this theme Until my eyelids will no longer blink.
# Output: why , i will fight with him upon this theme until my eyelids will no longer wag .
# 0.6026080978557137
# Input: If you’re not immortal, look around you.
# Output: if thou beest not immortal , look about you .
# 0.392814650900513
# Input: Not yet.
# Output: not yet .
# 0.8408964152537145
# Input: I beg you, be firm with him.
# Output: pray you , be doom s death with him .
# 0.6147881529512643
# Input: Why, look there!
# Output: why , look you !
# 0.7598356856515925
# Input: I don’t know what its intentions are, But, in the plainness and freedom of my opinion, This foretells some strange eruption to our state.
# Output: i know not what harm elth state , but , in the gross and scope of my opinion , this bodes some strange eruption to our state .
# 0.28489318277723963
# Input: Be assured, good Cassio, I will do All I can in your behalf.
# Output: be thou assur d , good cassio , i will do all thy behalf in all behalf .
# 0.392814650900513
# Input: He has ridden his prologue like a rough colt.
# Output: he hath rid his prologue like a rough colt he knows not the stop .
# 0.3498761149110956
# Input: And this weak and idle play about love, Doesn’t mean any more than a dream.
# Output: and this weak and idle idle theme , no more yielding but a dream .
# 0.20492887230352247
# Input: If you dare to fight today, come to the field; If not, come when you’ve got stomachs.
# Output: if you dare fight today , come to the field if not , when you have stomachs .
# 0.3450955755035758
# Input: And the queen too, and they should be here presently.
# Output: and the queen too , and that presently .
# 0.28319415510892393
# Input: Tell me.
# Output: tell me .
# 0.8408964152537145
# Input: You have slept well; Awake!
# Output: thou hast slept well awake .
# 0.5623413251903491
# Input: My name is Roderigo.
# Output: my name is roderigo .
# 0.6389431042462724
# Input: My lord?
# Output: my lord ?
# 0.8408964152537145
# Input: Don’t dislike me for my complexion, The dark clothing of the polished sun, To whom I am a neighbor, and born near it.
# Output: mislike me not for my complexion , the shadowed livery of the burnish d sun , to whom i am a neighbour , and near bred .
# 0.2592494576098376
# Input: Don’t let me hold you up, Cassius, go if you like; I'll leave you.
# Output: let me not hinder , cassius , your desires , your desires i ll leave you .
# 0.4406401630925028
# Input: How am I false?
# Output: how am i false ?
# 0.8408964152537145
# Input: I think it was to see my mother's wedding.
# Output: i think it was to see my mother s wedding .
# 0.537284965911771
# Input: Then murder's out of tune, And sweet revenge grows harsh.
# Output: then murder s out of tune , and sweet revenge grows harsh .
# 0.33932513407933634
# Input: Your case, dear friend, Shall be my authority for what I do: as you go to Milan, I'll come by Naples.
# Output: thy case , dear friend , shall be my precedent as thou got milan , i ll come by naples .
# 0.23519902490068528
# Input: It is faded, And rather like a dream than a definite Memory in my mind.
# Output: it is far off , and rather like a dream than an assurance that my remembrance warrants .
# 0.24903286388467735
# Input: At home, my lord.
# Output: at home , my lord .
# 0.7071067811865476
# Input: So, goodbye for now.
# Output: so , fare you well .
# 0
# Input: Do it, England, Because, he rages like the pace of my blood, And you must cure me.
# Output: do it , england , for like the hectic in my blood he rages , and thou must cure me .
# 0.33271889139709504
# Input: What news can you tell me of my lord?
# Output: what tidings can you tell me of my lord ?
# 0.7259795291154771
# Input: am not I your lord?
# Output: am not i your lord ?
# 0.7952707287670506
# Input: Nor I.
# Output: nor i .
# 0
# Input: O Caesar, read mine first, because mine's a suit That touches Caesar nearer.
# Output: o caesar , read mine first , for mine s a suit that touches caesar nearer .
# 0.31314224813827346
# Input: Away!
# Output: away !
# 0
# Input: O, look, Titinius, look, the enemy flies!
# Output: o , look , titinius , look , the villains fly !
# 0.5169731539571706
# Input: What said he when he came to?
# Output: what said he when he came unto himself ?
# 0.5169731539571706
# Input: I don’t know where he lives; and for me to make up a lodging, and say he lies here or he lies there is to lie in my own throat.
# Output: i know not , whither he lives and for me to die a lodging and say he lies here , he lies there lies in my throat to lie in mine own throat .
# 0.446845229918357
# Input: Have you not dropped from heaven?
# Output: hast thou not dropped from heaven ?
# 0.5081327481546147
# Input: Where has Caesar deserved your loves like this?
# Output: wherein hath caesar thus deserved your loves ?
# 0.3564026463354183
# Input: O gentle son, Sprinkle cool patience on the heat and flame of your Anger!
# Output: o gentle son , upon the heat and flame of thy distemper sprinkle cool patience !
# 0.3407806467081348
# Input: Who has a breast so pure That some unclean thoughts Keep court records and legal holidays, and sit in session With lawful deliberations?
# Output: who hath a breast so pure , that some uncleanly apprehension keep leets and lawdays , and in session sit in session lawful ?
# 0.16737506462732374
# Input: Must I endure all this?
# Output: must i endure all this ?
# 0.5623413251903491
# Input: My lord, we were sent for.
# Output: my lord , we were sent for .
# 0.7598356856515925
# Input: Good sir, this ring was given me by my wife; And, when she put it on, she made me vow That I should not sell, or give, or lose it.
# Output: good sir , this ring was given me by my wife and , when she put it on , she made me vow that i should neither sell , nor give , nor give , nor give , nor
# 0.5057133385213529
# Input: How does my good Lord Hamlet?
# Output: how does my good lord hamlet ?
# 0.4728708045015879
# Input: With this, I leave — that, as I killed my best friend for the good of Rome, I have the same dagger for myself, to be used when it shall please my country to need my death.
# Output: with this , i depart in that dear friend my dear friend , i have but thine own other and better shall be paid for my country .
# 0.23140493434916112
# Input: My husband!
# Output: my husband !
# 0.8408964152537145
# Input: Until I know it is done, However great my luck, my joys can never begin.
# Output: till i know it is done , howe er my joys d , my joys were ne er begun .
# 0.17694975149532557
# Input: What do you call the carriages?
# Output: what call you the carriages ?
# 0.5475182535069453
# Input: Give your sorrow words.
# Output: your sorrow words .
# 0.7165313105737893
# Input: It is a very excited flood; I cannot, between the sky and the land, See a sail.
# Output: it is a very wrought flood i cannot , twixt the heaven and the main , descry a sail .
# 0.3146660996956416
# Input: but what o' that?
# Output: but what o that ?
# 1.0
# Input: What do I see on you?
# Output: what do i see on thee ?
# 0.5623413251903491
# Input: Do so;— and let no man pay for this deed But we who did it.
# Output: do so , and let no man abide this deed but we the doers .
# 0.29485531037430235
# Input: murder!
# Output: murder !
# 1.0
# Input: Lend me a garter.
# Output: lend me a garter .
# 0.7071067811865476
# Input: If this is true, then I should know this secret.
# Output: if this be true , then should i know this secret .
# 0.4132584091896901
# Input: Go to bed, Francisco.
# Output: get thee to bed , francisco .
# 0.5623413251903491
# Input: Good friend, go to him; because, by this light of heaven, I don’t know how I lost him.
# Output: good friend , go to him , for by this heavenly heaven , i know not how i lost him .
# 0.197516957569183
# Input: Yes, sir, for three months.
# Output: ay , sir , for three months .
# 0.668740304976422
# Input: Why Doesn’t then make our eyelids close?
# Output: why doth it not then our eyelids sink ?
# 0.48109772909788073
# Input: O King Stephano!
# Output: o king stephano !
# 0
# Input: With your permission, hostess.
# Output: by your leave , hostess .
# 0.8408964152537145
# Input: Well, you do what’s best.
# Output: well , thou dost best .
# 0.5506953149031838
# Input: You wrong me every way, you wrong me, Brutus.
# Output: you wrong me every way , you wrong me , brutus .
# 0.7259795291154771
# Input: This will only lead to another argument if I stay longer.
# Output: we will hold friends to longer .
# 0.3654520756092885
# Input: She swoons to see them bleed.
# Output: she swoons to see them bleed .
# 0.7598356856515925
# Input: A very changeable rogue, having no further conscience than assuming the mere form of civil and humane behavior, for the better measure of his worth and very hidden loose affections?
# Output: a very brave knave , having no further , having no further than if honor be your foil , for the better and fashion of his poor world .
# 0.2446355134568494
# Input: Indeed, she is a very fresh and delicate creature.
# Output: indeed she is a most fresh and delicate creature .
# 0.43167001068522526
# Input: I will fetch off my bottle, although I’ll be head over heels in muck for my efforts.
# Output: i will fetch off my bottle , though i be o er ears for my labour .
# 0.2560418203788593
# Input: For heaven's sake, help me!
# Output: for heaven s sake , help me !
# 0.4728708045015879
# Input: Such love must be treason in my breast.
# Output: such love must needs be treason in my breast .
# 0.5133450480401704
# Input: I will chop her into pieces.
# Output: i will chop her into messes .
# 0.5081327481546147
# Input: If you are Prospero, Give us details of how you were saved; How you have met us here, who were wrecked On this shore three hours ago, where I have lost,— How sharp the point of this memory is!— My dear son Ferdinand.
# Output: if you are prospero of our hours have broke our senses to heaven lives what wretches under this ecstasy hast tempest have deserved our librarity to since i have cast by this pay for money
# 0.22783395345285296
# Input: Stop thinking about it, Because nature, the moon, does not grow alone In strength and size, but as this temple grows, The inward duty of the mind and soul Grows wide along with the rest.
# Output: stop on t , for nature , for the moon , doth not greatly de to be armed in their amend but this same estiross .
# 0.18696002661918396
# Input: By heaven, I would rather have been his hangman.
# Output: by heaven , i rather would have been his hangman .
# 0.34329452398451965
# Input: Can you keep your heavy eyes open awhile, And play a song or two on your harp?
# Output: canst thou hold up thy heavy eyes a while , and play upon thy instrument a strain or two ?
# 0.4450050658086207
# Input: Six o’clock, at which time, my lord, You said our work should end.
# Output: on the sixth hour at which time , my lord , you said our work should cease .
# 0.4121183751323027
# Input: I am sorry, but heaven has decided it to be this way, To punish me with this act, and punish this act with me, That I must be their whip and whip-er.
# Output: i am sorry for thee , heaven hath serve myself to be move after their act , and do not presume to obey them after the custom .
# 0.33799676443682564
# Input: O notable prostitute!
# Output: o notable strumpet !
# 0.7598356856515925
# Input: What, is Brutus sick, And will he steal out of his wholesome bed To challenge the evil diseases of the night, And tempt the thick and unclean air To add to his sickness?
# Output: what , is brutus sick , and will he steal away with me on his peril , to challenge that the devil himself with a goodly worldy and ace to run on the devil common devil common youth
# 0.15384750052099497
# Input: None, Brutus, none.
# Output: none , brutus , none .
# 0.7598356856515925
# Input: My life on her faith in me!
# Output: my life upon her faith !
# 0.4171622699855093
# Input: to choose love by what another person sees!
# Output: to choose love by another s eyes .
# 0.3768499164492419
# Input: If every dollar in six thousand dollars Were in six parts, and every part a dollar, I would not take them; I want my promise to pay.
# Output: if every ducat in six thousand ducats were in six parts , every part loves , i would not take them to my bond .
# 0.18217996946985687
# Input: You yourself shall see the law; Because, as you insist on justice, be assured You shall have justice, more than you desire.
# Output: thyself shalt see the act for , as thou urgest justice , be assur d thou shalt have justice , more than thou desirest .
# 0.15085547916090875
# Input: Everyone swears to these conditions Who come to take a chance for my worthless self.
# Output: to these injunctions every one doth swear , that comes to hazard for my worthless self .
# 0.20333448190047881
# Input: We will get ourselves ready.
# Output: we will ourselves provide .
# 0.6548907866815301
# Input: No, my lord, I saw nothing.
# Output: no , my lord , i saw nothing .
# 0.7186082239261684
# Input: A dream itself is but a shadow.
# Output: a dream itself is but a shadow .
# 0.8091067115702212
# Input: It is here!
# Output: tis here .
# 0.510029457493824
# Input: Tell me, good Brutus, can you see your face?
# Output: tell me , good brutus , can you see your face ?
# 0.5133450480401704
# Input: Aren’t you a prostitute?
# Output: are not you a strumpet ?
# 0.5623413251903491
# Input: The spring, the summer, The pregnant autumn, and angry winter change Their usual clothes; and the amazed world, Now doesn’t know which is which by their apparel.
# Output: the spring , the higher to like the like flaming flaming like valery and the count which now hath no banged which now suppos withal .
# 0.3388626726433787
# Input: Cousins, I hope the days are near at hand That our homes will be safe.
# Output: cousins , i hope the days are near at hand that chambers will be safe .
# 0.49504302173760484
# Input: If only one of his pockets could speak, wouldn’t it say he lies?
# Output: if one of his pockets could speak , would it not say so ?
# 0.41249148923121126
# Input: When could they say, until now, those that talked about Rome, That her wide walls were ruled by only one man?
# Output: when could they say till now talk to rome that her wide walls enchang d grow ?
# 0.27179605481512953
# Input: I never knew a woman could love man so.
# Output: i never knew a woman love man so .
# 0.4412484512922977
# Input: Come, bring him away.
# Output: come , bring him away .
# 0.7071067811865476
# Input: In a minute!
# Output: knock knock knock knock knock knock knock anon !
# 0
# Input: Stay here at your own risk; I will go on alone.
# Output: stay at thy peril i will go .
# 0.2919441086311216
# Input: Be near at hand; I mess it up.
# Output: be near at hand i may miscarry in t .
# 0.3303164318013807
# Input: Go on; carry this.
# Output: go on this .
# 0.6474591278836639
# Input: and long live you to think so!
# Output: and long live you to think so !
# 1.0
# Input: O Hamlet, what a falling-off there was in our marriage!
# Output: o hamlet , what a falling off was there !
# 0.4026190971287384
# Input: Your voice shall be as strong as any man's In giving out the new honorable offices.
# Output: your voice shall be as strong as any man s in the dispines of the new dignities .
# 0.38538569180303145
# Input: Yes, my lord, if it pleases you.
# Output: ay , my lord , an t please you .
# 0.5169731539571706
# Input: Your spirit walks abroad, and turns our swords Into our own guts.
# Output: thy spirit walks abroad , and turns our swords in our own proper entrails .
# 0.5205510363053438
# Input: It would be good for you to do so much for charity.
# Output: twere good you do so much for charity .
# 0.34107725495137897
# Input: I won’t sort you with the rest of my servants, because, to speak to you like an honest man, I am most dreadfully attended.
# Output: i will not sort you with the rest of my servants for , to speak to you like an honest man , i am most dreadfully attended .
# 0.6444280974574026
# Input: Have things been quiet on your watch?
# Output: have you had quiet guard ?
# 0.4482700320176827
# Input: This was a way to thrive, and he was blest; And good luck is blessing, if men don’t steal it.
# Output: this was a way to thrive , and he was blest and thrift is blessing , if men steal it not .
# 0.5605920141892758
# Input: Do you think Alexander the Great looked like this in the earth?
# Output: dost thou think alexander looked o this fashion this earth ?
# 0.6511126026643229
# Input: fool!
# Output: fool !
# 1.0
# Input: Couldn’t a worm, a poisonous snake, do as much?
# Output: could not a worm , an adder , do so much ?
# 0.48549177170732344
# Input: I don’t, until you use them on me.
# Output: i do not , till you use them on me .
# 0.44632361378533286
# Input: There's none, or little of that.
# Output: there s none , nor little .
# 0.6511126026643229
# Input: No, unpin my hair.
# Output: no , unpin me here .
# 0.7071067811865476
# Input: God have mercy on his soul!
# Output: god have mercy on his soul !
# 0.7598356856515925
# Input: If we are like you in the rest, we’ll resemble you in that.
# Output: if we are like you in the rest , we will resemble you in that .
# 0.6162607099729586
# Input: Every man is on his own for all the rest, and let no man take care for himself, because all is only fortune.—Coragio!
# Output: every man is for all the rest , and let no man take care for himself for himself for himself for himself is but fortune .
# 0.5020344159181033
# Input: What man is that?
# Output: what man is that ?
# 0.7071067811865476
# Input: Can any prayers get through to you?
# Output: can no prayers pierce thee ?
# 0.4482700320176827
# Input: Tonight we host a solemn supper, sir, And I'll request your presence.
# Output: tonight we hold a solemn supper , sir , and i ll request your presence .
# 0.2891784933232572
# Input: Shall I do such a deed?
# Output: shall i do such a deed ?
# 0.5081327481546147
# Input: Why do you cross me in this command?
# Output: why do you cross me in this exigent ?
# 0.6803749333171202
# Input: Get out, tawny barbarian, out!
# Output: out , tawny tartar , out !
# 0.5506953149031837
# Input: This might be the head of a politician, which this ass now reaches over one that would go around God, might it not?
# Output: this might be the pate of a politician , which this ass o erreaches one that would circumvent god , might it not ?
# 0.35829898789498416
# Input: We are sent from our royal master, To give you thanks; Only to bring you, announced, into his sight, Not just pay you for your brave deeds.
# Output: we are sent to give thee from our royal master , to bring thee but to bring thee face of his sight , not pay thee worthy sight .
# 0.13619898795706048
# Input: When I was with him, I heard him swear To Tubal and to Chus, his countrymen, That he would rather have Antonio's flesh Than twenty times the value of the sum That he owed him; and I know, my lord, If law, authority, and power, don’t deny him, It will go hard with poor Antonio.
# Output: when i did know his pleasure i heard him swear to tubal , his countrymen into the debt , that he hath forbid my dearest pleasure to pay the execution of his enemy .
# 0.08813073712804784
# Input: Look, look again!
# Output: look to t , i charge again !
# 0.7598356856515925
# Input: Well then, now.
# Output: well then , now be you .
# 0.5623413251903491
# Input: Oh most happy hour!
# Output: o most happy hour !
# 0.7071067811865476
# Input: What, not a whore?
# Output: what , not a whore ?
# 0.7071067811865476
# Input: For that reason, good Brutus, get ready to hear what I have to say; And since you know you can’t see yourself Except in a mirror, I’ll be your mirror, And will modestly let you see That in yourself which you don’t know about.
# Output: for this , good brutus , put thee to these woes i have to hear thee and do thee know not , for i will not meet thee to know thy harm .
# 0.22336026258603678
# Input: There's never a villain dwelling in all Denmark Except that he's an arrant knave.
# Output: there s ne er villain in all all denmark but he s an arrant knave .
# 0.28495577603220296
# Input: O, balmy breath, that almost persuades Justice to break her sword!
# Output: o , balmy breath , that dost almost persuade justice to break her sword !
# 0.317023313852343
# Input: There are some men that don’t love a dead pig; Some that are crazy if they see a cat; And others, when they hear the song of the bagpipe, Cannot hold their urine, because sympathy, Mistress of passion, persuades passion to the mood Of what it likes or hates.
# Output: there are some bloody act for their own scaroracle if they behold a witness to see what they hear and vent the pipe , then not change the infinite pipe .
# 0.23488955690594004
# Input: I am a fool To cry at what I am happy about.
# Output: i am a fool to weep at what i am glad of .
# 0.34172334076593075
# Input: O, don’t be afraid of me.
# Output: o , fear me not !
# 0.42888194248035344
# Input: No, my good lord.
# Output: no , my good lord .
# 0.7071067811865476
# Input: Caesar should be a beast without a heart, If he stays at home today because he’s afraid.
# Output: caesar should be a beast without a heart if he fail not at home .
# 0.396558785524626
# Input: Whoa, ha, hey!
# Output: wo , ha , ho !
# 0.7598356856515925
# Input: Do you see, gentlemen?
# Output: do you see , gentlemen ?
# 0.7071067811865476
# Input: Who is here so vile that he will not love his country?
# Output: who is here here so vile that will not love his country ?
# 0.5637560315259289
# Input: Ha, they pluck out my eyes!
# Output: ha , they pluck out mine eyes !
# 0.5081327481546147
# Input: Lo!
# Output: lo !
# 0
# Input: I don’t value my life at the price of a pin, And as for my soul, what can it do to that, Being a thing that is immortal as it is?
# Output: i do not set my life at a pin s fee and for my soul , what can it do to that , being a thing immortal as itself ?
# 0.34845946044325965
# Input: Speak!
# Output: speak !
# 0
# Input: None, man: all are idle whores and rogues.
# Output: none , man all idle whores and knaves .
# 0.44815260192961937
# Input: Their shadows seem like A killing canopy under which Our army lies, ready to surrender.
# Output: their shadows seem a canopy most fatal , under which our army lies , ready to give up the ghost .
# 0.18710158230410626
# Input: I shall grow jealous of you shortly, Launcelot, if you thus get my wife into corners.
# Output: i shall grow jealous of you shortly , launcelot , if you thus get my wife into corners .
# 0.7447819789879647
# Input: Our wars are over.
# Output: our wars are done .
# 0.6389431042462724
# Input: I shall also have cause to speak of that, And directly from his mouth whose voice will deliver it.
# Output: i shall have cause of that , and directly in his tongue will deliver his tongue will become it .
# 0.5293250970845792
# Input: Portia!
# Output: portia ?
# 0
# Input: I think he’ll stand with us very strongly.
# Output: i think he will stand very strong with us .
# 0.5133450480401704
# Input: Come, my lord.
# Output: come , my lord .
# 0.7598356856515925
# Input: Reputation is an idle and very false burden, often got without merit and lost without being deserved.
# Output: reputation is an idle and most false imposition oft got without merit and lost without deserving .
# 0.4405136963304348
# Input: Fit the action to the word, the word to the action, with this special rule, that you don’t overstep the simplicity of being natural, for anything so overdone is not the purpose of playing, whose end, both at the first and now, was and is, to hold, as it were, the mirror up to nature, to show truth in reality, scorn her falseness, and his form and force to the very age and body of the time.
# Output: the air doth scorn the word and made to the story of the broil as brown and since the true truth which the deep innovation , and true which thou most does .
# 0.10635194042659613
# Input: Thanks for being on time.
# Output: for this good time i thank you .
# 0.7311104457090247
# Input: What news, my lord?
# Output: what news , my lord ?
# 0.7071067811865476
# Input: Sir, in Algeria.
# Output: sir , in algiers .
# 0.7598356856515925
# Input: So, bare your chest.
# Output: therefore lay bare your bosom .
# 0.5623413251903491
# Input: There is one that can rule Naples As well as the man who is sleeping, lords that can talk As much and unnecessarily As this Gonzalo: I myself could make Asses of these lords .
# Output: there is one person that can be as masterless , as well as i have cast these horded in the main of these kind of companies .
# 0.34529620013120943
# Input: O Julius Caesar, you’re mighty yet!
# Output: o julius caesar , thou art mighty yet !
# 0.4671379777282001
# ...
# 0.8633400213704505
# Input: The enemy comes on in a show full of noble daring; Their bloody sign of battle is hung out, And something has to be done immediately.
# Output: the enemy comes on in gallant show their bloody sign of battle is hung out , and something to be done immediately .
# 0.4147474118990039
# Input: As of a man faithful and honorable.
# Output: of a man faithful and honourable .
# 0.6431870218238024
# Input: My lord, he has wrung from me my reluctant permission By asking me again and again, and I Finally had to give in.
# Output: he hath , my lord , wrung from me my slow leave by laboursome petition , and at last at last to lead the time .
# 0.1228749228144577
# Input: Unreal mockery, here!
# Output: unreal mockery , hence !
# 0.7598356856515925
# Input: You move your cunning ahead more and more.
# Output: you do advance your cunning more and more .
# 0.45966135761245924
# Input: Such as she says my lord said I was.
# Output: such as she says my lord did say i was .
# 0.4111336169005197
# Input: No, don’t go back.
# Output: nay , go not back .
# 0.8408964152537145
# Input: Only, peace!
# Output: but , peace !
# 0.8408964152537145
# Input: Oh, wise young judge, how I honor you!
# Output: o wise young judge , how i do beseech you !
# 0.3155984539112945
# Input: Shall they see us?
# Output: shall they see us ?
# 0.7071067811865476
# Input: I cannot think you are my son.
# Output: i cannot think thou art my son as well as i did .
# 0.4961683000340363
# Input: Pretty soul!
# Output: pretty soul !
# 0.8408964152537145
# Input: You may Convey your pleasures in a spacious plenty, And yet seem cold, the time you may so deceive.
# Output: you may convey your pleasures in a spacious plenty and yet seem cold , the time you may so hoodwink .
# 0.6272517339014033
# Input: His absence, sir, Means he didn’t keep his promise.
# Output: his absence , sir , lays blame upon his promise .
# 0.5425486407251953
# Input: Fathers, from now on don’t believe you can know your daughters' minds from the way you see them act.
# Output: fathers , from hence trust not your daughters minds by what see them act .
# 0.26790084216236654
# Input: Are you acquainted with the difference of opinion That is the present question before the court?
# Output: are you acquainted with the difference that holds this present question in the court ?
# 0.29541521129385656
# Input: He is no crescent, and his horns are invisible within the circle.
# Output: he is no crescent , and his horns are invisible within the circumference .
# 0.8070557274927982
# Input: For England!
# Output: for england ?
# 0
# Input: What, ho!
# Output: what , ho !
# 0.8408964152537145
# Input: Who offered him the crown?
# Output: who offered him the crown ?
# 0.668740304976422
# Input: Heaven and your thoughts are witnesses that you are.
# Output: heaven and thy thoughts are witness that thou art .
# 0.48549177170732344
# Input: Most high, most mighty, and most powerful Caesar, Metellus Cimber falls before you Most humbly.
# Output: most high , most mighty , and most puissant caesar , metellus cimber throws before thy seat an humble heart .
# 0.2240750868020436
# Input: Do so; and after two days, I will set you free.
# Output: do so , and after two days i will discharge thee .
# 0.37200908038405156
# Input: Of so high and full intelligence and imagination!
# Output: of so high and plenteous wit and invention !
# 0.392814650900513
# Input: You naughty, Deceitful man, what’s your trade?
# Output: thou naughty knave , what trade ?
# 0.5330859115179258
# Input: Lorenzo and his infidel?
# Output: lorenzo and his infidel ?
# 0.7071067811865476
# Input: But, I beg you, don’t let any of your people wake me up; I feel a deep sleep coming.
# Output: but , i pray you , let none of your people stir me i have an exposition come upon me .
# 0.21047837785657153
# Input: That was my lady's voice.
# Output: that was my lady s voice .
# 0.5623413251903491
# Input: Aside.
# Output: aside .
# 0
# Input: First, noble friend, Let me embrace you, whose honor can’t Be measured or confined.
# Output: first , noble friend , let me embrace thine in love , whose honor cannot be measured .
# 0.5828233954152654
# Input: Will you laugh me asleep, because I am exhausted?
# Output: will you laugh me asleep , for i am very heavy ?
# 0.2777619034011791
# Input: She might lie by an emperor's side and order him to work.
# Output: she may lie by an emperor s side and command him tasks .
# 0.34172334076593075
# Input: Then it is he; the rest That are nobles Are already in the court.
# Output: then tis he the rest that are within the court .
# 0.2665429557589629
# Input: Fear it, Ophelia, fear it, my dear sister, And keep your affections deep within you, Out of the range and danger of desire.
# Output: fear it , ophelia , fear it , my dear sister , and keep in the rear of your affection , out of the shot and danger of desire .
# 0.28489318277723963
# Input: Come, you are too moral.
# Output: come , you are too severe a moraler .
# 0.4111336169005197
# Input: What!
# Output: what !
# 0
# Input: Do you see the ghastliness of her eye?
# Output: do you perceive the gastness of her eye ?
# 0.4153509237206396
# Input: Yes, you would argue for a score of kingdoms, And I would call it fair play.
# Output: yes , you shall seal of kingdoms of kingdoms and i would call it fair play .
# 0.27369311450967493
# Input: The worthy Baron of Ross.
# Output: the worthy thane of ross .
# 0.7952707287670506
# Input: It must be self-offense.
# Output: it must be se offendendo it must be else .
# 0.408248290463863
# Input: Now, God help you, poor monkey!
# Output: now , god help thee , poor monkey !
# 0.5623413251903491
# Input: No, but ask my opinion too about that.
# Output: nay , but ask my opinion too of that .
# 0.5410822690539396
# Input: She’s dead.
# Output: she s dead .
# 0.7598356856515925
# Input: I beg you, come in.
# Output: pray you , come in .
# 0.5506953149031838
# Input: Go softly on.
# Output: soft , soft !
# 0
# Input: You rogue!
# Output: you rogue !
# 0.8408964152537145
# Input: murder, murder!
# Output: murder , murder !
# 1.0
# Input: She says enough; yet she's a simple rabbit That cannot say as much.
# Output: she says enough yet she s a simple bawd that cannot say as much .
# 0.2865612242047131
# Input: Welcome, good Marcellus.
# Output: welcome , good marcellus .
# 0.7598356856515925
# Input: I’ll do that, my lord.
# Output: i ll do that , my lord .
# 0.5081327481546147
# Input: Tonight, I will throw writings in his windows, All tending to the great opinion that Rome holds his name, by several different hands, as if they came from several citizens, In these writings, I will analyze, although obscurely, Caesar's ambition.
# Output: tonight , i will put in s mind s eyes no man to the great report that is gratiano his names , report into the greener of this .
# 0.10101828343982086
# Input: Still, don’t be afraid Scotland has harvests enough to satisfy you, Of your very own.
# Output: yet fear not , fear stands not scotland is to woo your own .
# 0.5506953149031838
# Input: Not for you either.
# Output: nor for yours neither .
# 0.7071067811865476
# Input: That we should, with joy, pleasure, partying, and applause, transform ourselves into beasts!
# Output: that we should , with joy , pleasance , revel , and applause , transform ourselves into beasts !
# 0.5783569866465142
# Input: O!
# Output: o !
# 0
# Input: Must I remember?
# Output: must i remember ?
# 0.7598356856515925
# Input: And immediately come yourselves and Bring Messala with you to us.
# Output: and come yourselves and bring messala with you immediately to us .
# 0.4240125351805037
# Input: What need we fear who knows it, when none can call our power to account?
# Output: what need we fear who knows it , when none can call our power to account ?
# 0.9253911813809743
# Input: You sleep, and I will hold you in my arms.
# Output: sleep thou , and i will wind thee in my arms .
# 0.35930411196308426
# Input: Come, be a man.
# Output: come , be a man .
# 0.7071067811865476
# Input: Do I wrong my enemies?
# Output: wrong i mine enemies ?
# 0.6548907866815301
# Input: We really like this news, And later when we have more time we'll read this Request, answer, and think upon this business.
# Output: we speak this in more news , and these time we ll read this answer , answer .
# 0.28532185931104886
# Input: Where are you going?
# Output: whither away ?
# 0
# Input: Though this island seems to be deserted,— Ha, ha, ha!
# Output: though this island seem to be desert , to sebastian ha , ha !
# 0.6360188027707555
# Input: They vanished strangely.
# Output: they vanished strangely .
# 0.7598356856515925
# Input: Thank you so much.
# Output: i thank you .
# 0.5444460596606694
# Input: Widow!
# Output: widow ?
# 0
# Input: The old proverb is very well parted between my master Shylock and you, sir: you have the grace of God, sir, and he has enough.
# Output: the old proverb is very well parted between my master shylock and you , sir you have the grace of god , sir , and he hath enough .
# 0.6523366701420595
# Input: And stand indebted, over and above, In love and service to you forever.
# Output: and stand indebted , over and above , in love and service to you evermore .
# 0.5783569866465142
# Input: Mass, I cannot tell.
# Output: mass , i cannot tell .
# 0.6389431042462724
# Input: I'll tell you what you shall do.
# Output: i will tell you what you shall do .
# 0.6803749333171202
# Input: And, noble Signior, If virtue is missing delightful beauty, Your son-in-law is far more just than black.
# Output: and , noble signior , if virtue no delighted beauty lack , your son in law is far more fair than black .
# 0.2534743707366162
# Input: Didn’t you hear a noise?
# Output: didst thou not hear a noise ?
# 0.4728708045015879
# Input: God, God, forgive us all!
# Output: fore us all , god forgive us all !
# 0.4111336169005197
# Input: They met me on the day we won the battle, and I have learned by the most perfect report that they have more in them than mortal knowledge.
# Output: they met me in the day of success , and i have learned by the perfectest report , they have more in them than mortal knowledge .
# 0.38009842510778313
# Input: Her funeral rites have been as far enlarged As we can enlarge.
# Output: her obsequies have been as far enlarged as we can warrante .
# 0.36846158142668817
# Input: Come, go aside with me; I will leave so I can Equip me with some swift means of death For the beautiful devil.
# Output: come , go with me apart i will withdraw , to furnish me with some swift means of the fair devil .
# 0.2515065302858586
# Input: The King and Prince are saying prayers!
# Output: the king and prince at prayers !
# 0.6431870218238024
# Input: It was a brute part of him to kill so capital a stupid fellow there.
# Output: it was a brute part of him to kill so capital a calf there .
# 0.7210179410842105
# Input: My lord, you acted once when you were in the university, you say?
# Output: my lord , you play d once in the university , you say ?
# 0.34786351577524227
# Input: Before I started seeing Lysander, Athens seemed like a paradise to me.
# Output: before the time i did lysander see , seem like a paradise to me .
# 0.2891784933232572
# Input: Merciful heaven!
# Output: merciful heaven !
# 0.8408964152537145
# Input: You must tell his name and half his face must be seen through the lion's neck, and he himself must speak through the mask saying this, or something to the same defect,—"Ladies," or "Fair ladies, I would wish you, or, I would request you, or, I would entreat you, not to be afraid, not to tremble.
# Output: you must tell his name and half his bones must be seen through the lion s neck , he s look to you , nor the relish as show of it .
# 0.1382967620138454
# Input: I could find it in my heart to beat him,— Come, kiss.
# Output: i could find in my heart to beat him kiss .
# 0.4902608580435962
# Input: I see an angel that sees them.
# Output: i see a cherub that sees them .
# 0.4417918226831577
# Input: Are you some god, some angel, or some devil, That makes my blood cold and my hair to stand on end?
# Output: are you some god , some devil wife or some devil that makest my blood cold , and my hair to stare ?
# 0.45635645533679603
# Input: I am very glad that he's so out of hope.
# Output: i am very glad of his hope .
# 0.3043119239482219
# Input: When you hold up your hand that pure congealed white top, High Taurus' snow, fanned with the eastern wind, Turns to a crow.
# Output: when thou hold up thy hand , pure holy whiter wind , high tabourn , turns to a crow while with the crow ous wind !
# 0.24510735687589913
# Input: The meats baked for the funeral Were also put on the marriage tables.
# Output: the funeral baked meats did coldly furnish forth the marriage tables .
# 0.3181877033696365
# Input: Why there, there, there, there!
# Output: why there , there there , there , there !
# 0.5081327481546147
# Input: And I do think— or else this brain of mine Doesn’t know the trail of policy as surely As it used to do—, that I have found The very cause of Hamlet's lunacy.
# Output: and i do i think it of mine as the brains do know the peace of stain as it was as sure of his cause that i have to do b of it .
# 0.45434646027144593
# Input: By heaven I order you, speak!
# Output: by heaven i charge thee , speak !
# 0.7598356856515925
# Input: Goodbye.
# Output: farewell .
# 0
# Input: You can’t eat capons that way.
# Output: you cannot feed capons so .
# 0.5475182535069453
# Input: Noble Sebastian, You let your fortune sleep — die rather: wink While you are waking.
# Output: noble sebastian , thou let st thy fortune sleep die rather wink st whiles thou art waking .
# 0.24903286388467735
# Input: How did you know it was she?
# Output: how didst thou know she ?
# 0.5330859115179258
# Input: Nothing, good sir, but for you to help Mr. Cobweb scratch my head.
# Output: nothing , good monsieur , but to help cavalery cobweb to scratch .
# 0.3596611504718341
# Input: Don’t find any, conspiracy; Hide it in smiles and friendliness, Because, if you pass, your real face on, Not even the dark place between heaven and hell itself Is dim enough to hide you from being stopped.
# Output: be not order in smiles and smiles and smiles in smiles and cury knave , for if thou dull hell .
# 0.08264939465954706
# Input: A beautiful woman!
# Output: a fair woman !
# 0.7598356856515925
# Input: From this moment The very first wishes of my heart shall be The firs actions of my hand.
# Output: from this moment the very firstlings of my heart shall be the firstlings of my hand .
# 0.3041149081312327
# Input: O piteous spectacle!
# Output: o piteous spectacle !
# 0.7598356856515925
# Input: So, kneel down, and beg mercy of the Duke.
# Output: down , therefore , and beg mercy of the duke .
# 0.47750342648354643
# Input: Well, you shall see; your eyes shall be your judge, The difference of old Shylock and Bassanio:— What, Jessica!—You won’t eat like a glutton, As you have done with me;—What, Jessica!— And sleep and snore, and tear clothes apart— Why, Jessica, I say!
# Output: well , thou shalt see thy eyes shall be er and the difference of old shylock and my jessica , you will not .
# 0.11099325874273058
# Input: He is so full of courage, And his commendations are food for me, A banquet to me.
# Output: he is full so valiant , and his commendations i ll give him a banquet to me .
# 0.27310181471460565
# Input: How dare you Trade and traffic with Macbeth In riddles and affairs of death; And I, the mistress of your charms, The secret contriver of all harms, Was never called to offer my part, Or show the glory of our art?
# Output: how canst thou find a fever of the chamber and flying thy mistress and , the mistress like mistress of the mistress gentlewoman , to tender the bidding of all the dust ?
# 0.298647711047818
# Input: No, by my life and soul!
# Output: no , by my life , and soul !
# 0.7598356856515925
# Input: Get going, And, at the sunken place by the river Acheron, Meet me in the morning.
# Output: get you gone , and , at the pit of acheron meet me i the morning .
# 0.41970107748240365
# Input: So you shall hear Of carnal, bloody and unnatural acts, Of accidental judgments, casual slaughters, Of deaths planned by cunning and false causes, And, in this result, mistaken motives Fallen on the planners' heads.
# Output: therefore thou shalt hear of carnable and buy thy deservings , aught , lest of accidents affine , and damn d reason pang of thy painted air .
# 0.39198682396662266
# 0.5134450721975707

# %% [markdown]
# **Reference:**
# https://www.tensorflow.org/tutorials/text/transformer
